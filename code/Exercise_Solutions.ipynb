# %% [markdown]
# # Solutions to the OG-UN-Training Exercises
# ### by Jason DeBacker and Richard W. Evans, 2023

# %%
# imports
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import sys
import os
import ogcore

# %% [markdown]
# ## Standard Library Chapter Exercises
#
# 1. Use the `sys` module to create a relative path from a Python module, print that path.

# %%
# 1. Determine which of Python's built in objects (string, dict, list, tuple, set) are mutable and which are immutable.
a_string = "Alliteration"
try:
    a_string[0] = "B"
    print("Strings are mutable")
except TypeError:
    print("Strings are immutable")
a_dict = {"a": 1, "b": 2, "c": 3}
try:
    a_dict["a"] = 99
    # print("The new dictionary = ", a_dict)
    print("Dictionaries are mutable")
except TypeError:
    print("Dictionaries are immutable")
a_list = [1, 2, 3, 4, 5]
try:
    a_list[0] = 99
    # print("The new list =  ", a_list)
    print("Lists are mutable")
except TypeError:
    print("Lists are immutable")
a_set = {1, 2, 3, 4, 5}
try:
    a_set[0] = 99
    # print("The new set = ", a_set)
    print("Sets are mutable")
except TypeError:
    print("Sets are immutable")
a_tuple = (1, 2, 3, 4, 5)
try:
    a_tuple[0] = 99
    # print("The new tuple = ", a_tuple)
    print("Tuples are mutable")
except TypeError:
    print("Tuples are immutable")
an_int = 1
try:
    an_int = 99
    # print("The new int = ", an_int)
    print("Integers are mutable")
except TypeError:
    print("Integers are immutable")

# %%
# 2. Create a python module that prints something (e.g. `Hello World!`) and run it from the command line using `python module_name.py`.
# 3. Create a python notebook and run it in VS Code

# Can't replicate these in a notebook

# %%
# 4. Write a function that finds the Fibonacci sequence up to an integer `N` > 0 in the notebook.
# Now call this function for `N = 10` and `N=100`.
def fibo(N):
    assert N > 0  # raise error if N <= 0
    seq = [0]
    while seq[-1] <  N:
        if len(seq) == 1:
            seq.append(1)
        else:
            seq.append(seq[-1] + seq[-2])
    return seq[:-1]

print("Fibonacci series up to 10: ", fibo(10))
print("Fibonacci series up to 100: ", fibo(100))

# %%
# 5. Use the `sys` module to create a relative path from a Python module, print that path.
print("The relative path is: ", sys.path[0])

# %% [markdown]
# ## Object Oriented Programming Chapter Exercises

# %%
# 1. Define a class called `Specifications` with an attribute that is the rate of time preference, $\beta$.
# Create instances of this class called `p1` for $\beta=0.96$ and `p2` $\beta=0.99$.

class Specifications:
    def __init__(self, beta):
        self.beta = beta

p = Specifications(0.96)
q = Specifications(0.99)
print("Two instances of the Specifications class with different parameterizations of beta: ", p.beta, q.beta)

# %%
# 2. Update the `Specifications` class so that allows one to specify the
# value of $\beta$ upon initialization of the class and checks that $\beta$ is between 0 and 1.

class Specifications:
    def __init__(self, beta):
        assert 0 < beta < 1
        self.beta = beta
p = Specifications(0.96)
q = Specifications(0.99)
print("Two instances of the Specifications class with different parameterizations of beta: ", p.beta, q.beta)
# Try a beta out of range:
try:
    p3 = Specifications(1.01)
except AssertionError:
    print("Beta must be between 0 and 1")

# %%
# 3. Modify the `Specifications` class so that it has a method that prints the value of $\beta$.

class Specifications:
    def __init__(self, beta):
        assert 0 < beta < 1
        self.beta = beta

    def print_beta(self):
        print("Beta = ", self.beta)

# Test this:
p = Specifications(0.96)
p.print_beta()

# %%
# 4. Change the input of $\beta$ to the class so that it is input at an annual rate.
# Allow another attribute of the class called `S` that is the number of periods in
# an economic agent's life.  Include a method in the `Specifications` class that
# adjusts the value  the value of $\beta$ to represent the discount rate applied
# per model period, which will be equivalent to `S/80` years.

class Specifications:
    def __init__(self, beta_annual, S):
        assert 0 < beta_annual < 1
        self.beta_annual = beta_annual
        self.S = S

    def print_beta(self):
        print("Beta = ", self.beta_annual)

    def beta_adjust(self):
        self.beta = self.beta_annual ** (80 / self.S)

# Test this
p = Specifications(0.96, 80)
p.beta_adjust()
print("With" , p.S, "periods, Beta annual = ", p.beta_annual, " Beta per period = ", p.beta)
p2 = Specifications(0.96, 40)
p2.beta_adjust()
print("With" , p2.S, "periods, Beta annual = ", p2.beta_annual, " Beta per period = ", p2.beta)
p3 = Specifications(0.96, 10)
p3.beta_adjust()
print("With" , p3.S, "periods, Beta annual = ", p3.beta_annual, " Beta per period = ", p3.beta)

# %%
# 5. Add a method to the `Specifications` class that allows one to update the
# values of the class attributes `S` and `beta_annual` by providing a
# dictionary of the form `{"S": 40, "beta_annual": 0.8}`.
# Ensure that when the instance is updated, the new `beta` attribute is
# consistent with the new `S` and `beta_annual`.

class Specifications:
    def __init__(self, beta_annual, S):
        assert 0 < beta_annual < 1
        self.beta_annual = beta_annual
        self.S = S

    def print_beta(self):
        print("Beta = ", self.beta_annual)

    def beta_adjust(self):
        self.beta = self.beta_annual ** (80 / self.S)

    def update(self, new_dict):
        for key, value in new_dict.items():
            setattr(self, key, value)
        self.beta_adjust()

# Test this
p = Specifications(0.96, 80)
p.beta_adjust()
print("With" , p.S, "periods, Beta annual = ", p.beta_annual, " Beta per period = ", p.beta)
p.update({"S": 40, "beta_annual": 0.8})
print("With" , p.S, "periods, Beta annual = ", p.beta_annual, " Beta per period = ", p.beta)

# %% [markdown]
# ## Numpy Chapter Excercies

# %%
# 1. Create a matrix b
b = np.array([[1.1, 2.2, 3.0, 2.0, 1.0], [3.3, 4.4, 5.0, 3.7, 2.0]])
print("b = ", b)
print("b.shape = ", b.shape)
# Use the `shape` method of Numpy arrays to print the shape of this matrix.
# Use array slicing to print the first row of `b`, which represents the
# lifecycle savings decisions of the first agent (i.e., the amount they
# choose to save in each of their 5 periods of life).  Use array slicing
# to print the second column of `b`, which is the saves of both agents
# when they are in their second period of life.  Finally, use array
# slicing to print the first two rows and the last three columns of `b`
# (i.e., the savings of both agents from middle age onwards).
print("First row of b = ", b[0, :])
print("Second column of b = ", b[:, 1])
print("First two rows and last three columns of b = ", b[0:2, 2:5])

# %%
# 2. Define `Omega` and compute the dot product of b and the transpose of Omega
Omega = np.array([[0.05, 0.05, 0.08, 0.06, 0.2], [0.12, 0.16, 0.03, 0.2, 0.05]])
B = np.dot(b, Omega.T)
print("B = ", B)
print("The diagonal elements of B have some meaning.\n " +
      "The top left is the total savings of all type 1 agents (across cohorts).\n " +
      "The bottom right is the total savings of all type 2 agents (across cohorts).\n " +
      "The off-diagonal elements of B have no meaning since these are the \n " +
      "sum of one types savings with another types weights.")

# %%
# 3. Multiply the matrix `b` by the matrix `Omega` element-wise (Hadamard product).  Use the `np.array.sum()` method on the resulting matrix to find the total savings of each cohort.
C = b * Omega
print("Savings by cohort = ", C.sum(axis=0))

# %%
# 3. In one line, create a matrix of zeros that is the same size as `b`.
b_zeros = np.zeros_like(b)
print("Matrix of zeros like b = ", b_zeros)

# %%
# 4. Use `np.where` to return the elements of `b` that are greater than 2.0 and zero elsewhere.
b_gt2 = np.where(b > 2.0, b, b_zeros)
print("Indices of elements of b that are greater than 2.0 = ", b_gt2)
print(b_gt2.shape)

# %%
# 5. Now suppose a 3rd type of agent.
# This agent has savings $b_3 = \[4.1, 5.1, 7.1, 4.5, 0.9]$.
# Use `np.vstack` to stack `b` on top of `b_3` to create a new matrix `b_new`.
b_3 = np.array([4.1, 5.1, 7.1, 4.5, 0.9])
b_new = np.vstack((b, b_3))
print("New b matrix with 3 types of agents = ", b_new)

# %% [markdown]
# ## Pandas Chapter Exercises

# %%
# 1. Creat a dataframe from a dictionary
gdppc_dict = {
    "Year": [1990, 2000, 2010, 2018],
    "IND": [2087, 2753, 4526, 6806],
    "MYS": [8179, 13475, 18574, 24842],
    "USA": [36982, 45886, 49267, 55335],
}
df = pd.DataFrame(gdppc_dict)
print(df)

# %%
# 2. Inspect this data frame.  Print `df.head(3)`.  Print `df.tail(3)`.
# Get a list of column names with the `keys` method.
#Finally, use the  `describe` method to print descriptive statistics.
print("DataFrame head = ", df.head(3))
print("DataFrame tail = ", df.tail(3))
print("DataFrame column names = ", df.keys())
print("DataFrame descriptive statistics = ", df.describe())

# %%
# 3. Pandas DataFrame use an index to keep track of rows.
# Not the default index in `df` are integers for each row.
# Let's change the index so the year is the index value. Print the updated DataFrame.
df = df.set_index("Year")
print("DataFrame with year as index = ", df)

# %%
# 4. Let's reshape this into a long panel format with a `MultiIndex` for the columns.
# The first level of the `MultiIndex` should be the year and the second level should be the country.
# The values should be the GDP per capita.  To do this, use the pivottable. Print the DataFrame.
df = pd.DataFrame(df.stack())
# name the country index
df = df.rename_axis(index=("Year", "Country"))
df.rename(columns={df.columns[0]:"GDP per capita"}, inplace=True)
df

# %%
# 5. Create a new variable that is the GDP growth rate from the prior period measure.
# Using `groupby` to find mean GDP growth rate for each country ove the sample.
df["GDP pc Growth"] = df["GDP per capita"].groupby("Country").pct_change()
print("DataFrame with GDP growth = ", df)

# %%
# 6. Print a DataFrame as a table (e.g. to tex or json or md)
print(df.reset_index().to_markdown(index=False))

# %%
# 7. Read in a csv file as a DataFrame.
url = "https://raw.githubusercontent.com/EAPD-DRB/OG-ZAF/main/ogzaf/data/demographic/un_zaf_pop.csv"
df = pd.read_csv(url, sep="|",  header=1)
print(df.head(n=5))

# %%
# 8. Keep only the rows and columns that you need.
zaf_pop = df.loc[(df.TimeLabel == 2021) & (df.SexId == 3), ["AgeStart", "Value"]]
print(zaf_pop.head(n=5))

# %%
# 9. Rename column and create a density variable
zaf_pop.rename(columns={"Value": "Count"}, inplace=True)
zaf_pop["Density"] = zaf_pop.Count / zaf_pop.Count.sum()
print(zaf_pop.head(n=5))

# %%
# 10. Use the `plot` method to plot the population density across age for South Africa.
zaf_pop.plot(x="AgeStart", y="Density", title="South Africa Population Density by Age", xlabel="Age", ylabel="Density")

# %%
# 11. Create a data from that has the population density of women and then merge that to `zaf_pop`. Plot the distributions across age overall and for women
df = pd.read_csv(url, sep="|",  header=1)
zaf_female_pop = df.loc[(df.TimeLabel == 2021) & (df.SexId == 2), ["AgeStart", "Value"]]
zaf_female_pop.rename(columns={"Value": "Female Count"}, inplace=True)
zaf_female_pop["Female Density"] = zaf_female_pop["Female Count"] / zaf_female_pop["Female Count"].sum()
zaf_pop = zaf_pop.merge(zaf_female_pop, on="AgeStart", how="inner")
zaf_pop.plot(x="AgeStart", y=["Density", "Female Density"], title="South Africa Population Density by Age and Gender", xlabel="Age", ylabel="Density")

# %%
# 12. Save your final DataFrame to disk as a csv file.
zaf_pop.to_csv("zaf_pop.csv", index=False)

# %% [markdown]
# # Scipy Chapter Exercises

# %%
# Scipy constraints optimization problem
# Trying to plot this in 2D, not very successfully
delta = 0.005
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z = X**2 * Y
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=True, fontsize=10)
# circle = lambda x: np.sqrt(1 - x**2)
# plt.plot(x, circle(x), label="Constraint")
ax.plot(np.cos(x), np.sin(x), linewidth=1)
plt.show()

# %%
circle = lambda x: np.sqrt(1 - x**2)
def z_func(x):
    return -x[0]**2 * x[1]
min_val = scipy.optimize.minimize(z_func, x0=[0.5, 0.5], bounds=[(-1, 1), (-1, 1)], constraints={"type": "eq", "fun": lambda x: x[0]**2 + x[1]**2 - 1})
print("Maximum value is: ", min_val["x"])

# %%
y = np.sqrt(1/3)
x = np.sqrt(2) * y
print("Maximum value found by hand is: ", [x, y])

# %%
# Scipy interpolation problem
x_full = np.linspace(-10, 10, 100)
y_full = np.sin(x_full)
plt.plot(x_full, y_full)
plt.show()

# %%
random_index = np.random.choice(np.arange(100), size=40, replace=False)
x = x_full[random_index]
y = y_full[random_index]
plt.scatter(x, y)

# %%
# interpolate function y = f(x)
y_hat = scipy.interpolate.interp1d(x, y, kind="cubic", fill_value="extrapolate")
plt.plot(x_full, y_hat(x_full))

# %% [markdown]
# # Simulating OG-Core Chapter Exercises

# %%
# SS simulation of change in corporate income tax:
# set paths to save output to
CUR_PATH = os.path.abspath("")#os.path.abspath(os.path.dirname(__file__))
baseline_dir = os.path.join(CUR_PATH, "Exercise_Simulations", "OUTPUT_BASELINE")
reform_dir = os.path.join(CUR_PATH, "Exercise_Simulations", "OUTPUT_REFORM")

# solve for baseline SS
p = ogcore.parameters.Specifications(
    output_base=baseline_dir,
    baseline=True,
)
ogcore.execute.runner(p, time_path=False)

p_reform = ogcore.parameters.Specifications(
    output_base = reform_dir,
    baseline_dir=baseline_dir,
    baseline = False,
)
# Solve for reform SS after changing the corporate income tax rate to 15%
p_reform.update_specifications({'cit_rate': [[0.15]]})
ogcore.execute.runner(p_reform, time_path=False)
# Out:
# making dir:  /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Simulations/OUTPUT
macro_table = ogcore.output_tables.macro_table_SS(base_ss, reform_ss)
print(macro_table.to_markdown())
# Out:
# | Variable                       |   Baseline |    Reform |   % Change (or pp diff) |
# |:-------------------------------|-----------:|----------:|------------------------:|
# | GDP ($\bar{Y}$)                |  0.603384  | 0.604562  |               0.195369  |
# | Consumption ($\bar{C}$)        |  0.45298   | 0.454529  |               0.341934  |
# | Capital Stock ($\bar{K}$)      |  1.82011   | 1.83368   |               0.745515  |
# | Labor ($\bar{L}$)              |  0.332965  | 0.332633  |              -0.0996191 |
# | Real interest rate ($\bar{r}$) |  0.0628498 | 0.0631404 |               0.462439  |
# | Wage rate ($\bar{w}$)          |  1.1779    | 1.18138   |               0.295282  |

# %% [markdown]
# # OG-Core Output Exercises

# %%
# Exercise 17.1: solve for SS with different betas, plot SS profiles
# set paths to save output to
CUR_PATH = os.path.abspath("")#os.path.abspath(os.path.dirname(__file__))
baseline_dir = os.path.join(CUR_PATH, "Exercise_Simulations", "OUTPUT_BASELINE")
reform_dir = os.path.join(CUR_PATH, "Exercise_Simulations", "OUTPUT_REFORM")

# solve for baseline SS
p = ogcore.parameters.Specifications(
    output_base=baseline_dir,
    baseline=True,
)
ogcore.execute.runner(p, time_path=False)

p_reform = ogcore.parameters.Specifications(
    output_base = reform_dir,
    baseline_dir=baseline_dir,
    baseline = False,
)
# Solve for reform SS after changing the corporate income tax rate to 15%
p_reform.update_specifications({'beta_annual': [0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9]})
ogcore.execute.runner(p_reform, time_path=False)
# Out:
# making dir:  /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Simulations/OUTPUT_BASELINE/SS
# making dir:  /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Simulations/OUTPUT_BASELINE/TPI
# In runner, baseline is  True
# SS using initial guess factors for r and TR of 1.0 and 1.0 , respectively.
# GE loop errors =  [0.0029774621683344854, 0.011501205823617064, -0.05894028548873331, 0.0, -0.0043467079700771905, 0.01323660057654155, 0.018291852120452104, 0.019839382979577106, 0.012123772596738408, 0.01442754351340857, 0.01749047463752358, 0.003488143028673749, -0.0003912037173069427, -0.03462467254527396]
# GE loop errors =  [0.002977462168331599, 0.011501205823614066, -0.05894028548871888, 0.0, -0.004346707970071417, 0.013236600576541503, 0.018291852120451913, 0.019839382979577283, 0.012123772596738386, 0.014427543513408527, 0.017490474637523585, 0.0034881430286737443, -0.0003912037173064223, -0.03462467254527425]
# GE loop errors =  [0.002977462168331599, 0.011501205823614066, -0.05894028548871888, 0.0, -0.004346707970071417, 0.013236600576541501, 0.018291852120451913, 0.019839382979577283, 0.012123772596738386, 0.014427543513408527, 0.01749047463752359, 0.003488143028673745, -0.0003912037173064223, -0.03462467254527425]
# GE loop errors =  [0.0029774602905737607, 0.01150120487441074, -0.058940280970232406, 0.0, -0.004346706108664722, 0.013236600703878254, 0.018291852288647492, 0.019839383143762882, 0.012123772693490747, 0.014427543625617734, 0.017490474795982237, 0.003488143065272412, -0.0003912035497798186, -0.03462467263569485]
# GE loop errors =  [0.002977462168331599, 0.011501204858018824, -0.05894028548871866, 0.0, -0.004346707970071306, 0.013236600576541505, 0.01829185212045192, 0.019839382979577286, 0.012123772596738384, 0.014427543513408529, 0.017490474637523585, 0.0034881430286737448, -0.00039120371730641534, -0.034624672545274265]
# GE loop errors =  [1.725122822371361e-11, 1.8567258841528655e-11, -1.9528956229919459e-10, 0.0, -5.874079000989241e-12, -8.389349978599192e-12, -1.0057218946535329e-11, -9.092605141036714e-12, -6.215731054859397e-12, -6.518631120999707e-12, -8.613035631932497e-12, -1.9389719864426613e-12, -5.286743265386917e-13]
# GE loop errors =  [1.1964040869116843e-13, 1.4986623053658832e-13, -5.183853346579781e-12, 0.0, -5.992983886926595e-13, -3.1137765976740894e-13, -3.361234901522181e-13, -2.8056723611058487e-13, -2.38970301880137e-13, -2.3034352203410435e-13, -3.0059114919378516e-13, -7.581912528364931e-14, -5.3936022315070886e-14]
# Iteration: 01  Distance:  1.7239524279596472e-11
# SS debt =  1.0440867921564594 0.013274360975901359
# IO:  (1, 1) , C:  (1,)
# Foreign debt holdings =  0.4176347168625838
# Foreign capital holdings =  0.14033551091666055
# resource constraint:  [-1.0513812e-13]
# Steady state government spending is negative to satisfy budget
# Checking constraints on capital, labor, and consumption.
# 	There were no violations of the constraints on labor  supply.
# 	There were no violations of the constraints on  consumption.
# Maximum error in labor FOC =  1.6431300764452317e-13
# Maximum error in savings FOC =  1.9628743075372768e-13
# JUST SAVED SS output to  /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Simulations/OUTPUT_REFORM/SS/SS_vars.pkl
# /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages/ogcore/SS.py:1410: UserWarning: Warning: The combination of the tax policy you specified and your target debt-to-GDP ratio results in an infeasible amount of government spending in order to close the budget (i.e., G < 0)
#   warnings.warn(
# It took 176.080983877182 seconds to get that part done.

# %%
base_ss =ogcore.utils.safe_read_pickle(os.path.join(baseline_dir, "SS", "SS_vars.pkl"))
reform_ss = ogcore.utils.safe_read_pickle(os.path.join(reform_dir, "SS", "SS_vars.pkl"))
base_params = ogcore.utils.safe_read_pickle(os.path.join(baseline_dir, "model_params.pkl"))
reform_params = ogcore.utils.safe_read_pickle(os.path.join(reform_dir, "model_params.pkl"))
ogcore.output_plots.ss_profiles(base_ss, base_params, reform_ss, reform_params)

# %%
# Exercise 17.2
from io import BytesIO
import pickle
import requests
tpi_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/TPI_vars_baseline.pkl"
ss_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/SS_vars_baseline.pkl"
model_params_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/model_params_baseline.pkl"
r = requests.get(tpi_path)
tpi_output = pickle.loads(BytesIO(r.content).getvalue())
r = requests.get(ss_path)
ss_output = pickle.loads(BytesIO(r.content).getvalue())
r = requests.get(model_params_path)
model_params = pickle.loads(BytesIO(r.content).getvalue())

GDP_stationary_model_units = tpi_output["Y"]
T_vec = np.arange(0, tpi_output["Y"].shape[0])
GDP_non_stationary_model_units = GDP_stationary_model_units * np.exp(model_params["g_y"] * T_vec) * np.cumprod(1 + model_params["g_n"])
GDP_non_stationary_local_currency = GDP_non_stationary_model_units * ss_output["factor_ss"]
# plot GDP in local currency
plt.plot(GDP_non_stationary_local_currency)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb Cell 48 line 9
#       <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y106sZmlsZQ%3D%3D?line=6'>7</a> model_params_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/model_params_baseline.pkl"
#       <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y106sZmlsZQ%3D%3D?line=7'>8</a> r = requests.get(tpi_path)
# ----> <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y106sZmlsZQ%3D%3D?line=8'>9</a> tpi_output = pickle.loads(BytesIO(r.content).getvalue())
#      <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y106sZmlsZQ%3D%3D?line=9'>10</a> r = requests.get(ss_path)
#      <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y106sZmlsZQ%3D%3D?line=10'>11</a> ss_output = pickle.loads(BytesIO(r.content).getvalue())
#
# UnpicklingError: invalid load key, '{'.

# %%
# 17.3: Create macro tables
# First, read in model output
base_tpi_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/TPI_vars_baseline.pkl"
base_params_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/model_params_baseline.pkl"
reform_tpi_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/TPI_vars_reform.pkl"
reform_params_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/model_params_reform.pkl"
r = requests.get(base_tpi_path)
base_tpi = pickle.loads(BytesIO(r.content).getvalue())
r = requests.get(base_params_path)
base_params = pickle.loads(BytesIO(r.content).getvalue())
r = requests.get(reform_tpi_path)
reform_tpi = pickle.loads(BytesIO(r.content).getvalue())
r = requests.get(reform_params_path)
reform_params = pickle.loads(BytesIO(r.content).getvalue())
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb Cell 49 line 8
#       <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y110sZmlsZQ%3D%3D?line=5'>6</a> reform_params_path = "https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/model_params_reform.pkl"
#       <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y110sZmlsZQ%3D%3D?line=6'>7</a> r = requests.get(base_tpi_path)
# ----> <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y110sZmlsZQ%3D%3D?line=7'>8</a> base_tpi = pickle.loads(BytesIO(r.content).getvalue())
#       <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y110sZmlsZQ%3D%3D?line=8'>9</a> r = requests.get(base_params_path)
#      <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y110sZmlsZQ%3D%3D?line=9'>10</a> base_params = pickle.loads(BytesIO(r.content).getvalue())
#
# UnpicklingError: invalid load key, '{'.

# %%
# Now make the macro table
macro_table = ogcore.output_tables.macro_table_TPI(base_tpi, reform_tpi, base_params, reform_params)
print(macro_table.to_markdown())

# %%
# 17.4, Plot aggregates
ogcore.output_plots.macro_aggregates(base_tpi, reform_tpi, base_params, reform_params)

# %%
# 17.5, Plot aggregates relative to a baseline forecast
GDP_forecast = np.array([
    9798433.361, 9787825.404, 10132595.93, 10411531.32,
    10830994.35,11121729.09,11541296.74,12054563.71,
    12594777.57,13193437.33,13737993.55,13875146.34,
    14116809.36,14520719.97,15072347.37,15601870.36,16047299.44,
    16348375.08,16326046.51,15911894.12,16319838.19,16572931.77,
    16945747.72,17257902.13,17693831.73,18238008.17,18550137.99,
    18982853.58,19551667.62,19974213.89,19277860.06,20600684.21,
    21333157.94,21745600,22089590,22435530,22795090,23165430,23542450,
    23922220,24302080,24680650,25057260,25432210,25805950,26178950,
    26551860,26925870,27301970,27680920,28063300,28449620,28840510,
    29236180,29636360,30040560,30448430,30860520,31276660,31696400,
    32119290,32545110,32973750,33405240,33839410,34276180,34715910,
    35159850,35609030,36064460,36527240
])
ogcore.output_plots.macro_aggregates(
    base_tpi, reform_tpi, base_params,
    reform_params, plot_type="forecast", forecast_data=GDP_forecast)

# %% [markdown]
# # Calibration Chapter Exercises

# %%
# 1. Create a utility to get population data from the UN Population Prospects for a country of interest to you.
# The solution is to replace the `country_id` value of "710" with the number that is appropriate for your country (as a string)

# %%
# Exercise 18.2: Plot fertility rates for the country of interest
import ogzaf.demographics as demog  # change this to module created in (1)

fert_rates = demog.get_fert(100, download=True)
plt.plot(np.arange(0, 100), fert_rates)

# %%
# 18.3. Plot mortality rates for the country of interest
mort_rates, inf_mort_rate = demog.get_mort(100, download=True)
# graph saved in folder in working directory
plt.plot(np.arange(0, 100), mort_rates)

# %%
# 18.4: Return the population objects dictionary and plot the population distribution over several years
E = 20
S = 80
T = 320
curr_year = 2023
pop_objs = demog.get_pop_objs(E, S, T, curr_year, download=True)
# plots
pop_dist = pop_objs["omega"]
ages = np.linspace(20, 101, 80)
years = [0, 20, 100, 319]  # just use indexes here
for y in years:
    plt.plot(ages, pop_dist[y, :], label=2023 + y)
plt.legend()
plt.show()

# %%
# 18.5: Plot the population growth rate over time
years = np.linspace(1, T+1, T)
plt.plot(years, pop_objs["g_n"][:T])

# Then some description of the population growth rate rising or falling because fertility rates are high and mortality low (or vice versa)

# %%
# Exercise 18.6: Simulation with alternative demographics
# set paths to save output to
base_dir = os.path.join(CUR_PATH, "Exercise_Simulations", "OUTPUT_BASELINE")
reform_dir = os.path.join(CUR_PATH, "Exercise_Simulations", "OUTPUT_REFORM")
# baseline parameterization
p = Specifications(
    baseline=True,
    baseline_dir=base_dir,
    output_base=base_dir,
)
ogcore.execute.runner(p, time_path=False)
# "reform" parameterization
p2 = Specifications(
        baseline=False,
        baseline_dir=base_dir,
        output_base=reform_dir,
    )
pop_objs_dict = demog.get_pop_objs(p2.E, p2.S, p2.T, p2.start_year, download=True)
p2.update_specifications(pop_objs_dict)
ogcore.execute.runner(p2, time_path=False)

# %%
# now compare output
base_ss = ogcore.utils.safe_read_pickle(os.path.join(base_dir, "SS", "SS_vars.pkl"))
reform_ss = ogcore.utils.safe_read_pickle(os.path.join(reform_dir, "SS", "SS_vars.pkl"))
macro_table = ogcore.output_tables.macro_table_SS(base_ss, reform_ss)
print(macro_table.to_markdown())

# %%
# Exercise 18.7: Using pandas data reader
import pandas_datareader as pdr
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 1, 1)
# FRED code for Real GDP in South Africa is NGDPRSAXDCZAQ
gdp = pdr.data.DataReader("NGDPRSAXDCZAQ", "fred", start, end)
# plot this series
plt.plot(gdp)

# %%
# Exercise 18.8: Turn this quarterly data into annual data
# First, get the annual average
gdp_annual = gdp.resample('Y').mean()
# plot this series
plt.plot(gdp_annual)

# %%
# Exercise 18.9: Plot the annual growth rate of GDP
gdp_growth = gdp_annual.pct_change()
gdp_growth = gdp_growth.dropna()
plt.plot(gdp_growth)

# %%
# Exercise 18.10: Estimate the autocorrelation of the annual growth rate of GDP
import statsmodels.regression.linear_model as lm
reg_model = lm.OLS(gdp_growth[1:].values, gdp_growth[:-1].values)
reg_results = reg_model.fit()
print(reg_results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.004
# Model:                            OLS   Adj. R-squared (uncentered):             -0.106
# Method:                 Least Squares   F-statistic:                            0.03832
# Date:                Wed, 06 Dec 2023   Prob (F-statistic):                       0.849
# Time:                        14:41:37   Log-Likelihood:                          21.864
# No. Observations:                  10   AIC:                                     -41.73
# Df Residuals:                       9   BIC:                                     -41.42
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0693      0.354     -0.196      0.849      -0.870       0.731
# ==============================================================================
# Omnibus:                       17.610   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.959
# Skew:                          -1.909   Prob(JB):                      0.00688
# Kurtosis:                       6.053   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Exercise 18.12: Find and plot earnings profiles from oguse.income module
! pip install ogusa
# Out:
# Collecting ogusa
#   Using cached ogusa-0.1.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (1.26.0)
# Requirement already satisfied: psutil in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (5.9.5)
# Requirement already satisfied: scipy>=1.5.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (1.11.3)
# Requirement already satisfied: pandas>=1.2.5 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (2.1.2)
# Requirement already satisfied: matplotlib in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (3.8.1)
# Requirement already satisfied: dask>=2.30.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (2023.11.0)
# Requirement already satisfied: distributed>=2.30.1 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (2023.11.0)
# Requirement already satisfied: paramtools>=0.15.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (0.18.1)
# Collecting taxcalc>=3.0.0 (from ogusa)
#   Using cached taxcalc-3.4.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: requests in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (2.31.0)
# Collecting rpy2<=3.5.11 (from ogusa)
#   Using cached rpy2-3.5.11.tar.gz (216 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas-datareader in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (0.10.0)
# Requirement already satisfied: xlwt in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (1.3.0)
# Requirement already satisfied: openpyxl>=3.1.2 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (3.1.2)
# Requirement already satisfied: statsmodels in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (0.14.0)
# Requirement already satisfied: linearmodels in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (5.3)
# Requirement already satisfied: wheel in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (0.41.3)
# Requirement already satisfied: ogcore in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from ogusa) (0.10.10)
# Requirement already satisfied: click>=8.1 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from dask>=2.30.0->ogusa) (6.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (1.0.7)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (2.0.7)
# Requirement already satisfied: zict>=3.0.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from distributed>=2.30.1->ogusa) (3.0.0)
# Requirement already satisfied: et-xmlfile in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from openpyxl>=3.1.2->ogusa) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from pandas>=1.2.5->ogusa) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from pandas>=1.2.5->ogusa) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from pandas>=1.2.5->ogusa) (2023.3)
# Requirement already satisfied: marshmallow>=3.0.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from paramtools>=0.15.0->ogusa) (3.20.1)
# Requirement already satisfied: cffi>=1.10.0 in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from rpy2<=3.5.11->ogusa) (1.16.0)
# Collecting tzlocal (from rpy2<=3.5.11->ogusa)
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: bokeh in /Users/jason.debacker/anaconda3/envs/un-og-training-dev/lib/python3.12/site-packages (from taxcalc>=3.0.0->ogusa) (3.3.0)
# Collecting numba (from taxcalc>=3.0.0->ogusa)
#   Using cached numba-0.58.1.tar.gz (2.6 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/bw/1cvntf9x02b49nfwgy_qnfn00000gp/T/pip-install-iaa0kdre/numba_0874164c6a40460d87848ad26c983706/setup.py", line 51, in <module>
#           _guard_py_ver()
#         File "/private/var/folders/bw/1cvntf9x02b49nfwgy_qnfn00000gp/T/pip-install-iaa0kdre/numba_0874164c6a40460d87848ad26c983706/setup.py", line 48, in _guard_py_ver
#           raise RuntimeError(msg.format(cur_py, min_py, max_py))
#       RuntimeError: Cannot install on Python version 3.12.0; only versions >=3.8,<3.12 are supported.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import ogusa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb Cell 66 line 1
# ----> <a href='vscode-notebook-cell:/Users/jason.debacker/repos/UN-OG-Training/code/Exercise_Solutions.ipynb#Y124sZmlsZQ%3D%3D?line=0'>1</a> import ogusa
#
# ModuleNotFoundError: No module named 'ogusa'

# %%
ogusa.income.get_e_interp(S, age_wgts, age_wgts_80, abil_wgts, plot=False)
